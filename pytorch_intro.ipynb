# %%
import torch

# %%
x = torch.tensor(1.0)
y = torch.tensor(2.0)

w = torch.tensor(1.0, requires_grad = True)

# %%
print(x)
print(y)
print(w)
# Out:
# tensor(1.)
# tensor(2.)
# tensor(1., requires_grad=True)

# %%
y_hat = w*x
s = y_hat - y
loss = (s)**2

# %%
print(loss)
print(loss.item())
# Out:
# tensor(1., grad_fn=<PowBackward0>)
# 1.0

# %%
loss.backward()

# %%
print(w.grad)
print(w.grad.item())
# Out:
# tensor(-2.)
# -2.0
